# %% [markdown]
# # Clase 1 Introduccion a Python

# %%
print("hola")
# Out:
# hola

# %% [markdown]
# ## Cargando las librerias

# %%
import numpy as np

# %%
x = 50
y = np.random.rand(x)
y
# Out:
# array([0.84231659, 0.585406  , 0.00317862, 0.51063908, 0.28212599,
#        0.00952474, 0.53897071, 0.47664815, 0.68199193, 0.81868968,
#        0.59487211, 0.60969666, 0.7984218 , 0.21986647, 0.40663173,
#        0.59488399, 0.86552043, 0.26191345, 0.64758935, 0.02154228,
#        0.53067801, 0.1225355 , 0.60271597, 0.33941902, 0.47605163,
#        0.1753043 , 0.95472485, 0.08826976, 0.8050037 , 0.50811213,
#        0.66395498, 0.88068136, 0.30618311, 0.34690277, 0.59631644,
#        0.62777091, 0.07589022, 0.6892926 , 0.74699536, 0.78493097,
#        0.88820552, 0.14759007, 0.76848446, 0.83337611, 0.75787177,
#        0.56567995, 0.71173162, 0.81105443, 0.18281124, 0.86443807])

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     nhanes_2015_2016.csv
# airline_data.csv           cwurData.csv   pokemon.csv
# antropometria00.csv        data.csv       sample_pivot.csv
# antropometria-dataset.csv  headbrain.csv  tips.csv
# Canada.xlsx                mic.xlsx       weight-height.csv
# Cartwheeldata.csv          movies.csv

# %% [markdown]
# ## Tipo de los datos

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
type(-3)
# Out:
# int

# %%
x = 'nombre1'
x
# Out:
# 'nombre1'

# %%
type(x)
# Out:
# str

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
numbers[0]
# Out:
# 1

# %%
sum_ = sum(numbers)
sum_
# Out:
# 15

# %%
length = len(numbers)
length
# Out:
# 5

# %%
promedio = sum_/length
promedio
# Out:
# 3.0

# %%
type(3/5)
# Out:
# float

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
type('math.pi')
# Out:
# str

# %%
numbers = [math.pi, 3/5, 4.0, 'nombre', True]
numbers
# Out:
# [3.141592653589793, 0.6, 4.0, 'nombre', True]

# %%
type(False)
# Out:
# bool

# %%
type(None)
# Out:
# NoneType

# %%
print(None)
# Out:
# None

# %%
x = 16
y = 8
if x < y:
    print('{} es menor que {}'.format(x,y))
else: 
    print (x, 'es mayor que', y)
# Out:
# 16 es mayor que 8

# %%
unalista = [True, 6<5, 1==3, None is None]
unalista
# Out:
# [True, False, False, True]

# %% [markdown]
# ## el uso del for loop

# %%
for element in unalista:
    print(element,'/t', type(element))
# Out:
# True /t <class 'bool'>
# False /t <class 'bool'>
# False /t <class 'bool'>
# True /t <class 'bool'>

# %% [markdown]
# ## lista

# %%
unalista = ['first', 'second', 'third' , 'fourth' , 'fifth' , 'sixth'
        ]
unalista
# Out:
# ['first', 'second', 'third', 'fourth', 'fifth', 'sixth']

# %%
unalista.sort()
unalista
# Out:
# ['fifth', 'first', 'fourth', 'second', 'sixth', 'third']

# %%
unalista [:2]
# Out:
# ['fifth', 'first']

# %%
unalista.sort()
unalista
# Out:
# ['fifth', 'first', 'fourth', 'second', 'sixth', 'third']

# %%
unalista[1:3]
# Out:
# ['first', 'fourth']

# %%
unalista[5]
# Out:
# 'third'

# %%
unalista[:-3]
# Out:
# ['fifth', 'first', 'fourth']
